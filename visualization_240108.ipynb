# %% [markdown]
# <a href="https://colab.research.google.com/github/JiHoonYoon00/mulcamp34/blob/main/visualization_240108.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

tips = sns.load_dataset("tips")

fig, ax = plt.subplots()
sns.scatterplot(x = 'total_bill', y = 'tip', hue = 'sex', data = tips)
plt.savefig("output/result.png")

plt.show()

# %%
tips = sns.load_dataset("tips")

fig, ax = plt.subplots()

ax.plot([1,2,3,4]) #matplotlib이용
sns.scatterplot(x = 'total_bill', y = 'tip', hue = 'sex',ax = ax, data = tips)  #seaborn이용
plt.savefig("output/result.png")

plt.show()

# %% [markdown]
# ## matplotlib와 seaborn을 동시에 사용한subplotting기법
# - 다중차트 하나의 도화지에 담기

# %%
fig, ax = plt.subplots()

plt.show()

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2)

plt.title('plt.title')

plt.show()

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2)

ax[0].set_title('ax[0] title')
ax[0].plot([1,2,3])

ax[1].set_title('ax[1] title')
sns.scatterplot(x = 'total_bill', y = 'tip', hue = 'sex',ax = ax[1], data = tips)


fig.suptitle('plt.title') #타이틀 제목

plt.show()

# %%
#https://matplotlib.org/stable/users/explain/axes/arranging_axes.html

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 2)

ax[0,0].set_title('ax[1] title')
ax[0,0].plot([1,2,3])

ax[0,1].set_title('ax[2] title')
sns.barplot(x = 'sex', y = 'tip', hue = 'sex',ax = ax[0,1], data = tips)

ax[1,0].set_title('ax[3] title')
sns.scatterplot(x = 'total_bill', y = 'tip', hue = 'day',ax = ax[1,0], data = tips) # ax넣어야함 주의

ax[1,1].set_title('ax[4] title')
sns.scatterplot(x = 'total_bill', y = 'tip', hue = 'sex',ax = ax[1,1], data = tips)


fig.suptitle('plt.title')
plt.tight_layout()
plt.show()
# Out:
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# ## 산점도 그래프
# - x축 y축 그래프 형태가 연속형 데이터가 와야함
# - 연속형 데이터의 예시 : 키 몸무게등 소숫점이 존재하는 데이터

# %%
fig, ax=plt.subplots(1, 2, figsize=(15, 5))

sns.regplot(x="total_bill", y="tip", data=tips, ax=ax[0], fit_reg=True) #fit_reg 평균축
ax[0].set_title('with linear regression line')

sns.regplot(x="total_bill", y="tip", data=tips, ax=ax[1], fit_reg=False)
ax[1].set_title('without linear regression line')

plt.show()
# 토탈빌이 높으면 팁도 증가하는 경향 , 토탈빌이 커질수록 분산이 커진다.

# %%
# 토탈빌이 높으면 팁도 증가하는 경향 , 토탈빌이 커질수록 분산이 커진다.

# %%
fig, ax = plt.subplots()

#sns.displot(x= 'tip', ax=ax, data=tips)
sns.histplot(x= 'tip', ax=ax, data=tips)
plt.show()
#2-4사이에 데이터가 몰려있다
# Out:
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
fig, ax =plt.subplots(nrows = 1 ,ncols = 2)
sns.boxplot(x = 'sex', y = 'tip', ax = ax[0], data = tips)
sns.scatterplot(x = 'total_bill',y ='tip',hue = 'sex', ax = ax[1], data = tips)
plt.show()

#하나의 차트만 보고 해석하면 안됨
#박스플랏(자격증용)은 이상치 데이터를 보여주는 장점이 있음
# Out:
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
fig, ax =plt.subplots(nrows = 1 ,ncols = 2,figsize =(10,6))
sns.boxplot(x = 'sex', y = 'tip', ax = ax[0], data = tips)
sns.swarmplot(x = 'sex', y = 'tip', ax = ax[0], data = tips,alpha = 0.25) #분포
sns.scatterplot(x = 'total_bill',y ='tip',hue = 'sex', ax = ax[1], data = tips)
plt.show()
# Out:
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
fig, ax =plt.subplots()
sns.countplot(x = 'day',data =tips)

plt.show()
# Out:
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
fig, ax =plt.subplots()
sns.countplot(x = 'day',data =tips,order = tips['day'].value_counts().index)

plt.show()
# Out:
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# ## 시각화 중급

# %%
tips['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %% [markdown]
# ### 라이브러리 가져오기

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator, FuncFormatter) # 축 설정할 때 값
import seaborn as sns
import numpy as np

# %% [markdown]
# ### 데이터 불러오기

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#y축 설정할때 소수점2자리까지 표현
def major_formatter(x, pos):
    return "%.2f$" % x
formatter = FuncFormatter(major_formatter)

# %% [markdown]
# ### 객체지향선언

# %%
fig, ax = plt.subplots(nrows =1 , ncols = 2,figsize = (16, 5))

#이상적인 막대그래프
ax0 = sns.barplot(x = "day", y = 'total_bill', data = tips,
                  errorbar=None, color='lightgray',zorder=2, alpha=0.85, ax=ax[0]) #zorder=2

group_mean = tips.groupby(['day'])['total_bill'].agg('mean')
h_day = group_mean.sort_values(ascending=False).index[0] # 해당되는 결괏값의 MAx값의 인덱스 요일을 하나 가져옴
h_mean = np.round(group_mean.sort_values(ascending=False)[0], 2) #해당되는 결괏값의 max값 하나를 가져옴
for p in ax0.patches:
  fontweight = "normal"
  color = "k"
  height = np.round(p.get_height(), 2)
  if h_mean == height:
    fontweight="bold"
    color="darkred"
    p.set_facecolor(color)
    p.set_edgecolor("black")
  ax0.text(p.get_x() + p.get_width()/2., height+1, height, ha = 'center',
           size=12,
           fontweight=fontweight, color=color)

# y축 범위 지정 옵션
ax0.set_ylim(-3, 30)
ax0.set_title("Ideal Bar Graph", size = 16)

# 가로세로 축, 일부 수정 및 변경
ax0.spines['top'].set_visible(False)
ax0.spines['left'].set_position(("outward", 20))
ax0.spines['left'].set_visible(False)
ax0.spines['right'].set_visible(False)

# y축 값 변경
ax0.yaxis.set_major_locator(MultipleLocator(10))
ax0.yaxis.set_major_formatter(formatter)
ax0.yaxis.set_minor_locator(MultipleLocator(5))

# y축 라벨 변경
ax0.set_ylabel("Avg. Total Bill($)", fontsize=14)

# y축 Grid 라인 수정
ax0.grid(axis="y", which="major", color="lightgray")
ax0.grid(axis="y", which="minor", ls=":")

# x축의 값을 변경
ax0.set_xlabel("Weekday", fontsize=14)
for xtick in ax0.get_xticklabels():
  print(xtick)
  if xtick.get_text() == h_day:
    xtick.set_color("darkred")
    xtick.set_fontweight("demibold")
ax0.set_xticklabels(['Thursday', 'Friday', 'Saturday', 'Sunday'], size=12)


#일반 막대그래프
ax1 = sns.barplot(x = "day", y = 'total_bill', data = tips, errorbar=None, alpha=0.85, ax=ax[1])
for p in ax1.patches:
  height = np.round(p.get_height(), 2)
  ax1.text(p.get_x() + p.get_width()/2., height+1, height, ha = 'center', size=12)
ax1.set_ylim(-3, 30)
ax1.set_title("Just Bar Graph")

plt.show()
# Out:
# Text(0, 0, 'Thur')
# Text(1, 0, 'Fri')
# Text(2, 0, 'Sat')
# Text(3, 0, 'Sun')
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /var/folders/dk/vy49vgx92_3d76t7s3b_x5c40000gn/T/ipykernel_56816/1695768675.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   group_mean = tips.groupby(['day'])['total_bill'].agg('mean')
# ...

# %% [markdown]
# ### 시각화 솔루션
# - 과연 저 코드들을 저렇게 사용하는게 맞나?
# - 파워포인트나 엑셀로 더 빠르고 눈에 보이기 쉽게 제작할수있는 능력을 기르자

# %%
penguins = sns.load_dataset("penguins")
sns.displot(penguins, x="flipper_length_mm")
# Out:
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.displot(penguins, x="flipper_length_mm", binwidth=3)
# Out:
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(penguins, x="flipper_length_mm")
# Out:
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(penguins, x="flipper_length_mm", bins=10)
# Out:
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
tips = sns.load_dataset("tips")
sns.displot(tips, x="size")
# Out:
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(tips, x="size", bins= [1,2,3,4,5,6,7]) # 칸을 나누는 의미
# Out:
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(tips, x="size", discrete=True)
# Out:
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(tips, x="day", shrink= .8)
# Out:
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## 펭귄처럼 자료형이 많은 경우 분포단위로 끊어서 x축을 구성하는게 좋고, 적을때는 tip처럼 구성해서 쓴다.

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species")
# Out:
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
fig, ax = plt.subplots(nrows = 1 , ncols = 2)

sns.displot(x="flipper_length_mm", hue="species", element="step", ax =ax[0], data = penguins)
sns.displot(x="flipper_length_mm", hue="island", element="step", ax = ax[1], data = penguins)
plt.show()

'''
fig, ax =plt.subplots(nrows = 1 ,ncols = 2)
sns.boxplot(x = 'sex', y = 'tip', ax = ax[0], data = tips)
sns.scatterplot(x = 'total_bill',y ='tip',hue = 'sex', ax = ax[1], data = tips)
plt.show()
'''
# Out:
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.displot(penguins, x="flipper_length_mm", hue="island", element="step")
# Out:
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
fig, ax = plt.subplots(1,2,figsize=(10,6))
sns.histplot(penguins, x="flipper_length_mm", hue="species", ax=ax[0])
sns.histplot(penguins, x="flipper_length_mm", hue="species", element="step", ax=ax[1])
plt.show()
# Out:
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
fig, ax = plt.subplots(1,2,figsize=(10,6))
sns.histplot(penguins, x="flipper_length_mm", hue="species", element="step", ax=ax[0])
sns.histplot(penguins, x="flipper_length_mm", hue="island", element="step", ax=ax[1])
plt.show()
# Out:
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yoonjihoon/anaconda3/envs/myenv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.scatterplot(x = 'island',y ='species', data = penguins)
# Out:
# <Axes: xlabel='island', ylabel='species'>

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...
